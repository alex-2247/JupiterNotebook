# %% [markdown]
# ## Первые шаги

# %%
print('ку-ку')
# Out:
# ку-ку

# %%
pip install isOdd
# Out:
# Requirement already satisfied: isOdd in c:\users\пользователь мс\appdata\local\programs\python\python310\lib\site-packages (0.1.2)Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\Users\Пользователь МС\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\пользователь мс\appdata\local\programs\python\python310\lib\site-packages (3.5.1)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\пользователь мс\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.29.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\пользователь мс\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\пользователь мс\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\пользователь мс\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\пользователь мс\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\пользователь мс\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\пользователь мс\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.0.7)
# Requirement already satisfied: numpy>=1.17 in c:\users\пользователь мс\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.22.2)
# WARNING: You are using pip version 21.2.4; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\Users\Пользователь МС\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: six>=1.5 in c:\users\пользователь мс\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import isOdd as io

# %%
a = "1"
print(io)
io(a)
# Out:
# <module 'isOdd' from 'C:\\Users\\Пользователь МС\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\isOdd\\__init__.py'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 3>()
#       1 a = "1"
#       2 print(io)
# ----> 3 io(a)
#
# TypeError: 'module' object is not callable

# %%
h = 0
while h< 10:
    h +=1

# %%
x = 2

# %%
x

# %%
x + 12

# %%
x = 11
y = 22
x + y

# %%
def fib(n):
    if n <= 1:
        return 1 
    else:
        return fib(n - 1) + fib(n - 2)

# %%
fib(14)

# %%
li = []
for i in range(1,10):
    li.append(i)
li

# %%
fibs = [(n, fib(n)) for n in range(1,10)]
fibs

# %% [markdown]
# ## Квадратные уравнения

# %%
from math import sqrt

def solve(a, b, c):
    d = b**2 - 4*a*c
    if d >= 0:
        x1 = (-b + sqrt(d)) / (2 * a)
        x2 = (-b - sqrt(d)) / (2 * a)
        return (x1, x2)
    else:
        return 'Вещественных корней нет'

# %%
solve(0.5, 0.125, 0)

# %%
solve(1, 2, 3)

# %%
z1 = complex(1, 2)
z2 = complex(3, 5)
z1, z2
# (z1, z2)

# %%
'z1 = ({}, {})'.format(z1.imag, z2.real)

# %%
import cmath

def csolve(a, b, c):
    d = b**2 - 4*a*c
    x1 = (-b + cmath.sqrt(d)) / (2 * a)
    x2 = (-b - cmath.sqrt(d)) / (2 * a)
    return (x1, x2)

# %%
csolve(1, 2, 5)

# %% [markdown]
# ## Пример использования Map

# %%
f = lambda x: x**3
list(map(f, range(1, 6)))

# %% [markdown]
# ##  [PIP](https://pypi.org/)

# %%
import matplotlib.pyplot as plt

# %%
import random

random.randint(1, 10)
# Out:
# 2

# %%
f = lambda x: random.randint(1, 10)
points = list(map(f, range(1, 10)))
points
# Out:
# [8, 3, 5, 7, 7, 6, 2, 3, 5]

# %%
p = plt.plot(points, 'b.')

# %%
plt.plot(points)
plt.show()

# %%
x = list(map(f, range(1, 10)))
y = list(map(f, range(1, 10)))
print(x)
print(y)
# ., , , o, v, ^, <	, >, 1, 2, 3, 4, 8, s, p, P, *, h, H, +, x, X, D, d, |, _, 
plt.plot(x, y, 'r1')
plt.show()
# Out:
# [1, 3, 10, 2, 4, 4, 2, 9, 10]
# [6, 8, 8, 7, 9, 6, 5, 2, 5]

# %%
x = list(range(1,200))
fx = [i*i for i in x]

# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.html?highlight=pyplot#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.axes.html#matplotlib.pyplot.axes

plt.axes(facecolor='white')
plt.plot(x,fx)
plt.show()

# %% [markdown]
# ### Настройки
# https://matplotlib.org/stable/tutorials/introductory/customizing.html

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

x = list(range(-200, 200))
fx = [i**2 + 2*i - 3 for i in x]

# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.html?highlight=pyplot#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.axes.html#matplotlib.pyplot.axes

mpl.rcParams['lines.linewidth'] = 2
mpl.rcParams['lines.linestyle'] = '-.' #'--'
mpl.rcParams['lines.color'] = 'C0'

plt.axes(facecolor='white')
plt.plot(x,fx)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1,2],[1,-1], 'r1', markerfacecolor = 'red')
plt.show()

# %%
import numpy as np
from math import sqrt
import matplotlib.pyplot as plt

x = list(range(0, 500, 2))
y = list(map(lambda a: sqrt(a),x))

fig, ax = plt.subplots()

ax.plot(x, y)
ax.grid()

#  Наименование осей
ax.set_xlabel('x')
ax.set_ylabel('sqrt(x)')
  
plt.show()

# %%
import matplotlib.pyplot as plt
import random

# random.randint(1, 10)

vx = [1.0,2.0,3.0]
vy = [1.0,2.0,1.0]

sx = vx[0]
sy = vy[0]

px = []
py = []

for i in range(1,10000):
    r = random.randint(0, 2)
    sx = (sx + vx[r]) / 2
    sy = (sy + vy[r]) / 2    
    px.append(sx)
    py.append(sy)
  
plt.plot(px, py, 'o')
plt.show()

# %%
import random
import matplotlib.pyplot as plt

x = [1.0,2.0,3.0]
y = [1.0,2.0,1.0]

sx = x[0]
sy = y[0]

px = []
py = []

for i in range(1,100000):
    r = random.randint(0, 2)
    sx = (sx + x[r]) / 2
    sy = (sy + y[r]) / 2    
    px.append(sx)
    py.append(sy)

fig, ax = plt.subplots()

# маркеры цветов 'b', 'g', 'r', 'c', 'm', 'y', 'k', 'w' , RGB: #00ff00
ax.scatter(px, py, c = 'red', s = 1)
ax.set_facecolor('black')

# ax.grid()
# ax.set_xlabel('')
# ax.set_ylabel('')
fig.set_figwidth(15)
fig.set_figheight(10)
plt.show()

# %% [markdown]
#  ![ку-ку](https://static.turbosquid.com/Preview/001207/528/WB/600.jpg "описание при наведении")

# %%
import random
import matplotlib.pyplot as plt

count = 400
x = list(range(1, 7))
y = [0 for i in x]

fig, ax = plt.subplots()

for _ in range(count):
    y[random.randint(0, 5)] += 1

ax.bar(x, y)
# 
y.sort()
#print('{}%'.format(round((y[5] - y[0]) / count * 100, 3)))
stat = [f'{i+1}: {round(y[i] / count * 100)}%' for i in range(0,6)]
print(stat)
plt.show()
# Out:
# ['1: 15%', '2: 16%', '3: 17%', '4: 17%', '5: 17%', '6: 18%']

# %%
from sympy import *
from sympy.plotting import plot
init_printing()

# %%
x = Symbol('x')

# %%
f = x + 2022
f
# Out:
# x + 2022

# %%
f.subs(x, -77)
# Out:
# 1945

# %%
f.subs(x,-210)
# Out:
# 1812

# %%
plot(f)
print(f)
# Out:
# x + 2022

# %%
g = sin(x+x)/x
plot(g)
print(g)
# Out:
# sin(2*x)/x

# %%
h = x**2
h
# Out:
#  2
# x

# %%
plot(h)
h
# Out:
#  2
# x

# %%
h=-h

# %%
plot(h)
h
# Out:
#   2
# -x

# %%
a = 1
b = 0
c = 0
h = a*x**2 + b*x+c
h
# Out:
#  2
# x

# %%
plot(h)
h
# Out:
#  2
# x

# %%
a = 1
b = 3
c = 4
h = a*x**2 + b*x+c
h
# Out:
#  2
# x  + 3⋅x + 4

# %%
plot(h)
h
# Out:
#  2
# x  + 3⋅x + 4

# %%
solve(h, x)
# Out:
# ⎡  3   √7⋅ⅈ    3   √7⋅ⅈ⎤
# ⎢- ─ - ────, - ─ + ────⎥
# ⎣  2    2      2    2  ⎦

# %%
q = x/(x+2)
q
# Out:
#   x
# ─────
# x + 2

# %%
plot(q)

# %%
fun1 = plot(q,(x,-10,-2.1), show=False)
fun2 = plot(q,(x,-1.9,10), show=False)
fun1.append(fun2[0])
fun1.show()

# %%
x = Symbol('x')
y = 1*x**2 + 2*x - 10
solve(y)

# %%
res = plot(y,(x,-5, 5))
